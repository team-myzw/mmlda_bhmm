# %% [markdown]
# # team myzw
# ### ToDo
# 逆強化学習
# 相対概念
# セマンティックマッピング
# シグバース
# 能動的地図学習
#
# TODO
# * 特徴量抽出
#  * wordコードブック作成
# 　* vision
#  * motion
# * mMLDA学習
# * BHMM学習
# * HMM学習[学習＋プランニング]
# * 言語からZの推定

# %% [markdown]
# ### 岩田さん　データ形成

# %%
iwata_data_path = "/home/robocup/Desktop/miyazawa_crest_2018/caption/"

# %%
try:
    os.mkdir(os.path.join(iwata_data_path,"RecogData"))
    os.mkdir(os.path.join(iwata_data_path,"RecogData/words"))
except:
    pass

# %%
ls /home/robocup/Desktop/miyazawa_crest_2018/caption/
# Out:
# RecogData/  task_10/     task_12.csv  task_3/     task_5.csv  task_8/
# task_0/     task_10.csv  task_13/     task_3.csv  task_6/     task_8.csv
# task_0.csv  task_11/     task_13.csv  task_4/     task_6.csv  task_9/
# task_1/     task_11.csv  task_2/      task_4.csv  task_7/     task_9.csv
# task_1.csv  task_12/     task_2.csv   task_5/     task_7.csv

# %%
import pandas as pd
import numpy as np
import MeCab
from word_client import WordClient
word_client = WordClient()
import glob
import os

# %%
objects_list = ["doa","re-zo-ko","box","PET"]
class_nums = [5,5,4,4]
START_CLASS = 5
END_CLASS = 6

# %%
task_list = []
action_list = []
caption_list = []
objects_list = []
correct_object = []
correct_motion = []
scene_id = 0
vision_eye = np.eye(4)

for task_id in range(14):
    action_num = len(glob.glob(os.path.join(iwata_data_path,"task_{0}".format(task_id),"action*")))
    for action_id in range(action_num):
        caption_path = os.path.join(iwata_data_path,"task_{0}/caption{1:03d}.txt".format(task_id,action_id))
        motions_path = os.path.join(iwata_data_path,"task_{0}/action{1:03d}.txt".format(task_id,action_id))
        motions = np.loadtxt(motions_path, delimiter=",", skiprows=1,dtype=np.int32)
        object_id = np.loadtxt(motions_path, delimiter=",", usecols=0,dtype=np.int32)[0]
        
        caption = pd.read_csv(caption_path,header=None)
        caption.columns = ["sentences"]
        caption["secne_id"] = scene_id
        caption_list.append(caption)
        objects_list.append(vision_eye[object_id])
        
        correct_object.append(object_id)
        correct_motion.append(object_id)
        
        motions = np.insert(motions,0,[START_CLASS,END_CLASS])
        motions = motions +  object_id*7
        tmp_motion_hists = []
        for i in range(7*4):
            tmp_motion_hists.append(len(np.where(motions==i)[0]))
        action_list.append(tmp_motion_hists)
        
        scene_id+= 1

# %%
np.savetxt(os.path.join(iwata_data_path,"RecogData/motion.Motion"),np.array(action_list),fmt="%d")
np.savetxt(os.path.join(iwata_data_path,"RecogData/vision.Object"),np.array(objects_list),fmt="%d")

np.savetxt(os.path.join(iwata_data_path,"RecogData/CorrectObject.txt"),np.array(correct_object),fmt="%d")
np.savetxt(os.path.join(iwata_data_path,"RecogData/CorrectMotion.txt"),np.array(correct_motion),fmt="%d")

# %%
caption_pd = pd.concat(caption_list,axis=0)

# %%
caption_pd
# Out:
#       sentences  secne_id
# 0         箱にしまう         0
# 1          箱に置く         0
# 2        箱に片付ける         0
# 0        箱に片付ける         1
# 1          箱に置く         1
# 2         箱にしまう         1
# 0     ペットボトルを掴む         2
# 1   ペットボトルを把持する         2
# 2     ペットボトルを持つ         2
# 0          箱に置く         3
# 1        箱に片付ける         3
# 2         箱に入れる         3
# 0     ペットボトルを持つ         4
# 1   ペットボトルを把持する         4
# 2     ペットボトルを拾う         4
# 0        箱に片付ける         5
# 1         箱に入れる         5
# 2          箱に置く         5
# 0      ドアを押し開ける         6
# 1        ドアを開ける         6
# 2         ドアを押す         6
# 0        冷蔵庫を開く         7
# 1       冷蔵庫を開ける         7
# 2        冷蔵庫を覗く         7
# 0        箱に片付ける         8
# 1         箱に入れる         8
# 2         箱にしまう         8
# 0     ペットボトルを持つ         9
# 1     ペットボトルを掴む         9
# 2     ペットボトルを拾う         9
# ..          ...       ...
# 0     ペットボトルを拾う       140
# 1     ペットボトルを掴む       140
# 2     ペットボトルを持つ       140
# 0         箱に入れる       141
# 1         箱にしまう       141
# 2        箱に片付ける       141
# 0   ペットボトルを把持する       142
# 1     ペットボトルを拾う       142
# 2     ペットボトルを持つ       142
# 0         箱にしまう       143
# 1          箱に置く       143
# 2        箱に片付ける       143
# 0     ペットボトルを掴む       144
# 1     ペットボトルを持つ       144
# 2     ペットボトルを拾う       144
# 0         箱にしまう       145
# 1          箱に置く       145
# 2         箱に入れる       145
# 0          箱に置く       146
# 1         箱に入れる       146
# 2        箱に片付ける       146
# 0        箱に片付ける       147
# 1          箱に置く       147
# 2         箱にしまう       147
# 0      ドアを押し開ける       148
# 1         ドアを開く       148
# 2        ドアを開ける       148
# 0        冷蔵庫を開く       149
# 1     冷蔵庫を引き開ける       149
# 2       冷蔵庫を開ける       149
#
# [450 rows x 2 columns]

# %%
caption_pd.sentences.to_csv(os.path.join(iwata_data_path,"RecogData/sentences.txt"),index=False)

# %%
for i in range(150):
    word_dir = os.path.join(iwata_data_path,"RecogData/words/{0:03d}".format(i))
    try:
        os.mkdir(word_dir)
    except:
        pass
    
    word_client.update(word_dir)
    word_client.setAccept()
    # word の処理
    for sen in caption_pd[caption_pd.secne_id==i].sentences.values:
        word_client.sentence_data_cb(sen)
    word_client.setReject()
    word_client.split_sentences(word_dir)
    word_client.sumalize_utter(word_dir)
    sentences_file_path = os.path.join(word_dir,"sentences.txt")
    word_client.update_word_codebook(sentences_file_path)
    word_client.words2histogram(
    os.path.join(word_dir,"sentences.txt"),
    os.path.join(word_dir,"hist.txt")
    )
    word_client.dump_codebook(os.path.join(word_dir,"codebook.txt"))
# Out:
# 箱 に 置く
#
# 箱 に 片付ける
#
# 箱 に しまう
#
# 箱 に 置く
#
# 箱 に しまう
#
# 箱 に 片付ける
#
# 箱 に 置く
#
# 箱 に しまう
#
# 箱 に 片付ける
#
# 箱 に 置く
#
# 箱 に 片付ける
#
# 箱 に しまう
#
# ペットボトル を 把持 する
#
# ペットボトル を 持つ
#
# ペットボトル を 掴む
#
# ペットボトル を 把持 する
#
# ペットボトル を 掴む
#
# ペットボトル を 持つ
#
# 箱 に 片付ける
#
# 箱 に 入れる
#
# 箱 に 置く
#
# 箱 に 片付ける
#
# 箱 に 置く
#
# 箱 に 入れる
#
# ペットボトル を 把持 する
#
# ペットボトル を 拾う
#
# ペットボトル を 持つ
#
# ペットボトル を 把持 する
#
# ペットボトル を 持つ
#
# ペットボトル を 拾う
#
# 箱 に 入れる
#
# 箱 に 置く
#
# 箱 に 片付ける
#
# 箱 に 入れる
#
# 箱 に 片付ける
#
# 箱 に 置く
#
# ドア を 開ける
#
# ドア を 押す
#
# ドア を 押し 開ける
#
# ドア を 開ける
#
# ドア を 押し 開ける
#
# ドア を 押す
#
# 冷蔵庫 を 開ける
#
# 冷蔵庫 を 覗く
#
# 冷蔵庫 を 開く
#
# 冷蔵庫 を 開ける
#
# 冷蔵庫 を 開く
#
# 冷蔵庫 を 覗く
#
# 箱 に 入れる
#
# 箱 に しまう
#
# 箱 に 片付ける
#
# 箱 に 入れる
#
# 箱 に 片付ける
#
# 箱 に しまう
#
# ペットボトル を 掴む
#
# ペットボトル を 拾う
#
# ペットボトル を 持つ
#
# ペットボトル を 掴む
#
# ペットボトル を 持つ
#
# ペットボトル を 拾う
#
# 箱 に 入れる
#
# 箱 に 置く
#
# 箱 に 片付ける
#
# 箱 に 入れる
#
# 箱 に 片付ける
#
# 箱 に 置く
#
# 箱 に 片付ける
#
# 箱 に 入れる
#
# 箱 に 置く
#
# 箱 に 片付ける
#
# 箱 に 置く
#
# 箱 に 入れる
#
# ドア を 押す
#
# ドア を 開く
#
# ドア を 開ける
#
# ドア を 押す
#
# ドア を 開ける
#
# ドア を 開く
#
# ペットボトル を 持つ
#
# ペットボトル を 拾う
#
# ペットボトル を 把持 する
#
# ペットボトル を 持つ
#
# ペットボトル を 把持 する
#
# ペットボトル を 拾う
#
# 箱 に 片付ける
#
# 箱 に 置く
#
# 箱 に しまう
#
# 箱 に 片付ける
#
# 箱 に しまう
#
# 箱 に 置く
#
# ペットボトル を 掴む
#
# ペットボトル を 持つ
#
# ペットボトル を 把持 する
#
# ペットボトル を 掴む
#
# ペットボトル を 把持 する
#
# ペットボトル を 持つ
#
# 箱 に 片付ける
#
# 箱 に 置く
#
# 箱 に 入れる
#
# 箱 に 片付ける
#
# 箱 に 入れる
#
# 箱 に 置く
#
# 箱 に 置く
#
# 箱 に 入れる
#
# 箱 に 片付ける
#
# 箱 に 置く
#
# 箱 に 片付ける
#
# 箱 に 入れる
#
# 冷蔵庫 を 開ける
#
# 冷蔵庫 を 開く
#
# 冷蔵庫 を 覗く
#
# 冷蔵庫 を 開ける
#
# 冷蔵庫 を 覗く
#
# 冷蔵庫 を 開く
#
# ペットボトル を 拾う
#
# ペットボトル を 掴む
#
# ペットボトル を 把持 する
#
# ペットボトル を 拾う
#
# ペットボトル を 把持 する
#
# ペットボトル を 掴む
#
# 箱 に 片付ける
#
# 箱 に しまう
#
# 箱 に 入れる
#
# 箱 に 片付ける
#
# 箱 に 入れる
#
# 箱 に しまう
#
# 箱 に 片付ける
#
# 箱 に 入れる
#
# 箱 に 置く
#
# 箱 に 片付ける
#
# 箱 に 置く
#
# 箱 に 入れる
#
# ペットボトル を 持つ
#
# ペットボトル を 拾う
#
# ペットボトル を 掴む
#
# ペットボトル を 持つ
#
# ペットボトル を 掴む
#
# ペットボトル を 拾う
#
# ペットボトル を 把持 する
#
# ペットボトル を 拾う
#
# ペットボトル を 持つ
#
# ペットボトル を 把持 する
#
# ペットボトル を 持つ
#
# ペットボトル を 拾う
#
# ペットボトル を 把持 する
#
# ペットボトル を 掴む
#
# ペットボトル を 拾う
#
# ペットボトル を 把持 する
#
# ペットボトル を 拾う
#
# ペットボトル を 掴む
#
# ペットボトル を 把持 する
#
# ペットボトル を 持つ
#
# ペットボトル を 拾う
#
# ペットボトル を 把持 する
#
# ペットボトル を 拾う
#
# ペットボトル を 持つ
#
# 箱 に 入れる
#
# 箱 に しまう
#
# 箱 に 置く
#
# 箱 に 入れる
#
# 箱 に 置く
#
# 箱 に しまう
#
# ペットボトル を 持つ
#
# ペットボトル を 把持 する
#
# ペットボトル を 拾う
#
# ペットボトル を 持つ
#
# ペットボトル を 拾う
#
# ペットボトル を 把持 する
#
# 箱 に しまう
#
# 箱 に 片付ける
#
# 箱 に 入れる
#
# 箱 に しまう
#
# 箱 に 入れる
#
# 箱 に 片付ける
#
# ペットボトル を 掴む
#
# ペットボトル を 持つ
#
# ペットボトル を 把持 する
#
# ペットボトル を 掴む
#
# ペットボトル を 把持 する
#
# ペットボトル を 持つ
#
# 箱 に 置く
#
# 箱 に しまう
#
# 箱 に 片付ける
#
# 箱 に 置く
#
# 箱 に 片付ける
#
# 箱 に しまう
#
# ドア を 開ける
#
# ドア を 押す
#
# ドア を 押し 開ける
#
# ドア を 開ける
#
# ドア を 押し 開ける
#
# ドア を 押す
#
# ドア を 開く
#
# ドア を 開ける
#
# ドア を 押す
#
# ドア を 開く
#
# ドア を 押す
#
# ドア を 開ける
#
# 冷蔵庫 を 引き 開ける
#
# 冷蔵庫 を 開く
#
# 冷蔵庫 を 開ける
#
# 冷蔵庫 を 引き 開ける
#
# 冷蔵庫 を 開ける
#
# 冷蔵庫 を 開く
#
# 箱 に しまう
#
# 箱 に 置く
#
# 箱 に 入れる
#
# 箱 に しまう
#
# 箱 に 入れる
#
# 箱 に 置く
#
# 箱 に 入れる
#
# 箱 に しまう
#
# 箱 に 置く
#
# 箱 に 入れる
#
# 箱 に 置く
#
# 箱 に しまう
#
# 箱 に 片付ける
#
# 箱 に しまう
#
# 箱 に 置く
#
# 箱 に 片付ける
#
# 箱 に 置く
#
# 箱 に しまう
#
# ペットボトル を 持つ
#
# ペットボトル を 拾う
#
# ペットボトル を 把持 する
#
# ペットボトル を 持つ
#
# ペットボトル を 把持 する
#
# ペットボトル を 拾う
#
# 箱 に しまう
#
# 箱 に 片付ける
#
# 箱 に 置く
#
# 箱 に しまう
#
# 箱 に 置く
#
# 箱 に 片付ける
#
# ペットボトル を 把持 する
#
# ペットボトル を 持つ
#
# ペットボトル を 掴む
#
# ペットボトル を 把持 する
#
# ペットボトル を 掴む
#
# ペットボトル を 持つ
#
# 箱 に 入れる
#
# 箱 に 片付ける
#
# 箱 に しまう
#
# 箱 に 入れる
#
# 箱 に しまう
#
# 箱 に 片付ける
#
# ドア を 押す
#
# ドア を 押し 開ける
#
# ドア を 開く
#
# ドア を 押す
#
# ドア を 開く
#
# ドア を 押し 開ける
#
# 冷蔵庫 を 開ける
#
# 冷蔵庫 を 開く
#
# 冷蔵庫 を 引き 開ける
#
# 冷蔵庫 を 開ける
#
# 冷蔵庫 を 引き 開ける
#
# 冷蔵庫 を 開く
#
# ペットボトル を 掴む
#
# ペットボトル を 拾う
#
# ペットボトル を 持つ
#
# ペットボトル を 掴む
#
# ペットボトル を 持つ
#
# ペットボトル を 拾う
#
# 箱 に しまう
#
# 箱 に 置く
#
# 箱 に 入れる
#
# 箱 に しまう
#
# 箱 に 入れる
#
# 箱 に 置く
#
# 箱 に 入れる
#
# 箱 に 片付ける
#
# 箱 に しまう
#
# 箱 に 入れる
#
# 箱 に しまう
#
# 箱 に 片付ける
#
# 箱 に しまう
#
# 箱 に 入れる
#
# 箱 に 置く
#
# 箱 に しまう
#
# 箱 に 置く
#
# 箱 に 入れる
#
# ペットボトル を 把持 する
#
# ペットボトル を 持つ
#
# ペットボトル を 拾う
#
# ペットボトル を 把持 する
#
# ペットボトル を 拾う
#
# ペットボトル を 持つ
#
# 箱 に 片付ける
#
# 箱 に 入れる
#
# 箱 に 置く
#
# 箱 に 片付ける
#
# 箱 に 置く
#
# 箱 に 入れる
#
# ペットボトル を 把持 する
#
# ペットボトル を 拾う
#
# ペットボトル を 掴む
#
# ペットボトル を 把持 する
#
# ペットボトル を 掴む
#
# ペットボトル を 拾う
#
# 箱 に しまう
#
# 箱 に 入れる
#
# 箱 に 片付ける
#
# 箱 に しまう
#
# 箱 に 片付ける
#
# 箱 に 入れる
#
# ドア を 押し 開ける
#
# ドア を 開ける
#
# ドア を 開く
#
# ドア を 押し 開ける
#
# ドア を 開く
#
# ドア を 開ける
#
# 冷蔵庫 を 覗く
#
# 冷蔵庫 を 引き 開ける
#
# 冷蔵庫 を 開く
#
# 冷蔵庫 を 覗く
#
# 冷蔵庫 を 開く
#
# 冷蔵庫 を 引き 開ける
#
# ペットボトル を 拾う
#
# ペットボトル を 掴む
#
# ペットボトル を 持つ
#
# ペットボトル を 拾う
#
# ペットボトル を 持つ
#
# ペットボトル を 掴む
#
# 箱 に 置く
#
# 箱 に 入れる
#
# 箱 に しまう
#
# 箱 に 置く
#
# 箱 に しまう
#
# 箱 に 入れる
#
# ペットボトル を 掴む
#
# ペットボトル を 把持 する
#
# ペットボトル を 持つ
#
# ペットボトル を 掴む
#
# ペットボトル を 持つ
#
# ペットボトル を 把持 する
#
# 箱 に 置く
#
# 箱 に 入れる
#
# 箱 に しまう
#
# 箱 に 置く
#
# 箱 に しまう
#
# 箱 に 入れる
#
# ペットボトル を 持つ
#
# ペットボトル を 把持 する
#
# ペットボトル を 拾う
#
# ペットボトル を 持つ
#
# ペットボトル を 拾う
#
# ペットボトル を 把持 する
#
# ペットボトル を 把持 する
#
# ペットボトル を 持つ
#
# ペットボトル を 掴む
#
# ペットボトル を 把持 する
#
# ペットボトル を 掴む
#
# ペットボトル を 持つ
#
# ペットボトル を 拾う
#
# ペットボトル を 把持 する
#
# ペットボトル を 持つ
#
# ペットボトル を 拾う
#
# ペットボトル を 持つ
#
# ペットボトル を 把持 する
#
# ペットボトル を 持つ
#
# ペットボトル を 拾う
#
# ペットボトル を 把持 する
#
# ペットボトル を 持つ
#
# ペットボトル を 把持 する
#
# ペットボトル を 拾う
#
# ペットボトル を 持つ
#
# ペットボトル を 把持 する
#
# ペットボトル を 拾う
#
# ペットボトル を 持つ
#
# ペットボトル を 拾う
#
# ペットボトル を 把持 する
#
# 箱 に しまう
#
# 箱 に 片付ける
#
# 箱 に 置く
#
# 箱 に しまう
#
# 箱 に 置く
#
# 箱 に 片付ける
#
# ペットボトル を 拾う
#
# ペットボトル を 把持 する
#
# ペットボトル を 掴む
#
# ペットボトル を 拾う
#
# ペットボトル を 掴む
#
# ペットボトル を 把持 する
#
# 箱 に しまう
#
# 箱 に 片付ける
#
# 箱 に 入れる
#
# 箱 に しまう
#
# 箱 に 入れる
#
# 箱 に 片付ける
#
# 箱 に 片付ける
#
# 箱 に しまう
#
# 箱 に 置く
#
# 箱 に 片付ける
#
# 箱 に 置く
#
# 箱 に しまう
#
# ドア を 押す
#
# ドア を 開ける
#
# ドア を 押し 開ける
#
# ドア を 押す
#
# ドア を 押し 開ける
#
# ドア を 開ける
#
# 冷蔵庫 を 引き 開ける
#
# 冷蔵庫 を 開ける
#
# 冷蔵庫 を 覗く
#
# 冷蔵庫 を 引き 開ける
#
# 冷蔵庫 を 覗く
#
# 冷蔵庫 を 開ける
#
# ペットボトル を 把持 する
#
# ペットボトル を 持つ
#
# ペットボトル を 掴む
#
# ペットボトル を 把持 する
#
# ペットボトル を 掴む
#
# ペットボトル を 持つ
#
# 箱 に 置く
#
# 箱 に 片付ける
#
# 箱 に 入れる
#
# 箱 に 置く
#
# 箱 に 入れる
#
# 箱 に 片付ける
#
# ペットボトル を 拾う
#
# ペットボトル を 掴む
#
# ペットボトル を 把持 する
#
# ペットボトル を 拾う
#
# ペットボトル を 把持 する
#
# ペットボトル を 掴む
#
# 箱 に 入れる
#
# 箱 に 置く
#
# 箱 に 片付ける
#
# 箱 に 入れる
#
# 箱 に 片付ける
#
# 箱 に 置く
#
# ペットボトル を 拾う
#
# ペットボトル を 把持 する
#
# ペットボトル を 掴む
#
# ペットボトル を 拾う
#
# ペットボトル を 掴む
#
# ペットボトル を 把持 する
#
# ペットボトル を 掴む
#
# ペットボトル を 把持 する
#
# ペットボトル を 拾う
#
# ペットボトル を 掴む
#
# ペットボトル を 拾う
#
# ペットボトル を 把持 する
#
# ペットボトル を 持つ
#
# ペットボトル を 拾う
#
# ペットボトル を 把持 する
#
# ペットボトル を 持つ
#
# ペットボトル を 把持 する
#
# ペットボトル を 拾う
#
# ペットボトル を 持つ
#
# ペットボトル を 掴む
#
# ペットボトル を 拾う
#
# ペットボトル を 持つ
#
# ペットボトル を 拾う
#
# ペットボトル を 掴む
#
# ペットボトル を 持つ
#
# ペットボトル を 掴む
#
# ペットボトル を 拾う
#
# ペットボトル を 持つ
#
# ペットボトル を 拾う
#
# ペットボトル を 掴む
#
# ペットボトル を 拾う
#
# ペットボトル を 把持 する
#
# ペットボトル を 持つ
#
# ペットボトル を 拾う
#
# ペットボトル を 持つ
#
# ペットボトル を 把持 する
#
# ペットボトル を 持つ
#
# ペットボトル を 把持 する
#
# ペットボトル を 掴む
#
# ペットボトル を 持つ
#
# ペットボトル を 掴む
#
# ペットボトル を 把持 する
#
# 箱 に 置く
#
# 箱 に 片付ける
#
# 箱 に しまう
#
# 箱 に 置く
#
# 箱 に しまう
#
# 箱 に 片付ける
#
# 箱 に 置く
#
# 箱 に しまう
#
# 箱 に 片付ける
#
# 箱 に 置く
#
# 箱 に 片付ける
#
# 箱 に しまう
#
# 箱 に 片付ける
#
# 箱 に しまう
#
# 箱 に 入れる
#
# 箱 に 片付ける
#
# 箱 に 入れる
#
# 箱 に しまう
#
# 箱 に しまう
#
# 箱 に 入れる
#
# 箱 に 片付ける
#
# 箱 に しまう
#
# 箱 に 片付ける
#
# 箱 に 入れる
#
# ドア を 開く
#
# ドア を 押し 開ける
#
# ドア を 開ける
#
# ドア を 開く
#
# ドア を 開ける
#
# ドア を 押し 開ける
#
# 冷蔵庫 を 覗く
#
# 冷蔵庫 を 開く
#
# 冷蔵庫 を 引き 開ける
#
# 冷蔵庫 を 覗く
#
# 冷蔵庫 を 引き 開ける
#
# 冷蔵庫 を 開く
#
# ペットボトル を 把持 する
#
# ペットボトル を 持つ
#
# ペットボトル を 拾う
#
# ペットボトル を 把持 する
#
# ペットボトル を 拾う
#
# ペットボトル を 持つ
#
# 箱 に しまう
#
# 箱 に 片付ける
#
# 箱 に 入れる
#
# 箱 に しまう
#
# 箱 に 入れる
#
# 箱 に 片付ける
#
# ペットボトル を 掴む
#
# ペットボトル を 拾う
#
# ペットボトル を 持つ
#
# ペットボトル を 掴む
#
# ペットボトル を 持つ
#
# ペットボトル を 拾う
#
# 箱 に 入れる
#
# 箱 に 片付ける
#
# 箱 に 置く
#
# 箱 に 入れる
#
# 箱 に 置く
#
# 箱 に 片付ける
#
# ペットボトル を 持つ
#
# ペットボトル を 掴む
#
# ペットボトル を 拾う
#
# ペットボトル を 持つ
#
# ペットボトル を 拾う
#
# ペットボトル を 掴む
#
# 箱 に 入れる
#
# 箱 に しまう
#
# 箱 に 置く
#
# 箱 に 入れる
#
# 箱 に 置く
#
# 箱 に しまう
#
# ペットボトル を 拾う
#
# ペットボトル を 掴む
#
# ペットボトル を 把持 する
#
# ペットボトル を 拾う
#
# ペットボトル を 把持 する
#
# ペットボトル を 掴む
#
# 箱 に 入れる
#
# 箱 に 片付ける
#
# 箱 に 置く
#
# 箱 に 入れる
#
# 箱 に 置く
#
# 箱 に 片付ける
#
# ドア を 押す
#
# ドア を 開く
#
# ドア を 開ける
#
# ドア を 押す
#
# ドア を 開ける
#
# ドア を 開く
#
# 冷蔵庫 を 引き 開ける
#
# 冷蔵庫 を 開ける
#
# 冷蔵庫 を 覗く
#
# 冷蔵庫 を 引き 開ける
#
# 冷蔵庫 を 覗く
#
# 冷蔵庫 を 開ける
#
# 箱 に 片付ける
#
# 箱 に 置く
#
# 箱 に 入れる
#
# 箱 に 片付ける
#
# 箱 に 入れる
#
# 箱 に 置く
#
# ペットボトル を 拾う
#
# ペットボトル を 把持 する
#
# ペットボトル を 持つ
#
# ペットボトル を 拾う
#
# ペットボトル を 持つ
#
# ペットボトル を 把持 する
#
# 箱 に 片付ける
#
# 箱 に しまう
#
# 箱 に 入れる
#
# 箱 に 片付ける
#
# 箱 に 入れる
#
# 箱 に しまう
#
# ペットボトル を 持つ
#
# ペットボトル を 拾う
#
# ペットボトル を 掴む
#
# ペットボトル を 持つ
#
# ペットボトル を 掴む
#
# ペットボトル を 拾う
#
# ペットボトル を 持つ
#
# ペットボトル を 掴む
#
# ペットボトル を 拾う
#
# ペットボトル を 持つ
#
# ペットボトル を 拾う
#
# ペットボトル を 掴む
#
# 箱 に 片付ける
#
# 箱 に 置く
#
# 箱 に しまう
#
# 箱 に 片付ける
#
# 箱 に しまう
#
# 箱 に 置く
#
# ペットボトル を 拾う
#
# ペットボトル を 掴む
#
# ペットボトル を 把持 する
#
# ペットボトル を 拾う
#
# ペットボトル を 把持 する
#
# ペットボトル を 掴む
#
# 箱 に 置く
#
# 箱 に 片付ける
#
# 箱 に しまう
#
# 箱 に 置く
#
# 箱 に しまう
#
# 箱 に 片付ける
#
# 箱 に 置く
#
# 箱 に 片付ける
#
# 箱 に しまう
#
# 箱 に 置く
#
# 箱 に しまう
#
# 箱 に 片付ける
#
# ドア を 開く
#
# ドア を 押し 開ける
#
# ドア を 押す
#
# ドア を 開く
#
# ドア を 押す
#
# ドア を 押し 開ける
#
# 冷蔵庫 を 開く
#
# 冷蔵庫 を 開ける
#
# 冷蔵庫 を 覗く
#
# 冷蔵庫 を 開く
#
# 冷蔵庫 を 覗く
#
# 冷蔵庫 を 開ける
#
# ペットボトル を 持つ
#
# ペットボトル を 把持 する
#
# ペットボトル を 掴む
#
# ペットボトル を 持つ
#
# ペットボトル を 掴む
#
# ペットボトル を 把持 する
#
# 箱 に しまう
#
# 箱 に 置く
#
# 箱 に 片付ける
#
# 箱 に しまう
#
# 箱 に 片付ける
#
# 箱 に 置く
#
# ペットボトル を 拾う
#
# ペットボトル を 掴む
#
# ペットボトル を 持つ
#
# ペットボトル を 拾う
#
# ペットボトル を 持つ
#
# ペットボトル を 掴む
#
# 箱 に 片付ける
#
# 箱 に 置く
#
# 箱 に 入れる
#
# 箱 に 片付ける
#
# 箱 に 入れる
#
# 箱 に 置く
#
# 箱 に 入れる
#
# 箱 に しまう
#
# 箱 に 片付ける
#
# 箱 に 入れる
#
# 箱 に 片付ける
#
# 箱 に しまう
#
# 箱 に しまう
#
# 箱 に 片付ける
#
# 箱 に 入れる
#
# 箱 に しまう
#
# 箱 に 入れる
#
# 箱 に 片付ける
#
# 箱 に 片付ける
#
# 箱 に しまう
#
# 箱 に 入れる
#
# 箱 に 片付ける
#
# 箱 に 入れる
#
# 箱 に しまう
#
# ドア を 押す
#
# ドア を 開ける
#
# ドア を 押し 開ける
#
# ドア を 押す
#
# ドア を 押し 開ける
#
# ドア を 開ける
#
# 冷蔵庫 を 覗く
#
# 冷蔵庫 を 開く
#
# 冷蔵庫 を 引き 開ける
#
# 冷蔵庫 を 覗く
#
# 冷蔵庫 を 引き 開ける
#
# 冷蔵庫 を 開く
#
# ペットボトル を 持つ
#
# ペットボトル を 把持 する
#
# ペットボトル を 掴む
#
# ペットボトル を 持つ
#
# ペットボトル を 掴む
#
# ペットボトル を 把持 する
#
# 箱 に 入れる
#
# 箱 に 置く
#
# 箱 に 片付ける
#
# 箱 に 入れる
#
# 箱 に 片付ける
#
# 箱 に 置く
#
# ペットボトル を 掴む
#
# ペットボトル を 把持 する
#
# ペットボトル を 拾う
#
# ペットボトル を 掴む
#
# ペットボトル を 拾う
#
# ペットボトル を 把持 する
#
# 箱 に しまう
#
# 箱 に 入れる
#
# 箱 に 片付ける
#
# 箱 に しまう
#
# 箱 に 片付ける
#
# 箱 に 入れる
#
# 箱 に 入れる
#
# 箱 に 片付ける
#
# 箱 に 置く
#
# 箱 に 入れる
#
# 箱 に 置く
#
# 箱 に 片付ける
#
# ペットボトル を 持つ
#
# ペットボトル を 把持 する
#
# ペットボトル を 拾う
#
# ペットボトル を 持つ
#
# ペットボトル を 拾う
#
# ペットボトル を 把持 する
#
# 箱 に しまう
#
# 箱 に 置く
#
# 箱 に 入れる
#
# 箱 に しまう
#
# 箱 に 入れる
#
# 箱 に 置く
#
# 箱 に 入れる
#
# 箱 に しまう
#
# 箱 に 片付ける
#
# 箱 に 入れる
#
# 箱 に 片付ける
#
# 箱 に しまう
#
# ドア を 開ける
#
# ドア を 押し 開ける
#
# ドア を 押す
#
# ドア を 開ける
#
# ドア を 押す
#
# ドア を 押し 開ける
#
# 冷蔵庫 を 開ける
#
# 冷蔵庫 を 覗く
#
# 冷蔵庫 を 開く
#
# 冷蔵庫 を 開ける
#
# 冷蔵庫 を 開く
#
# 冷蔵庫 を 覗く
#
# ペットボトル を 拾う
#
# ペットボトル を 持つ
#
# ペットボトル を 把持 する
#
# ペットボトル を 拾う
#
# ペットボトル を 把持 する
#
# ペットボトル を 持つ
#
# 箱 に 置く
#
# 箱 に 片付ける
#
# 箱 に しまう
#
# 箱 に 置く
#
# 箱 に しまう
#
# 箱 に 片付ける
#
# 箱 に しまう
#
# 箱 に 入れる
#
# 箱 に 置く
#
# 箱 に しまう
#
# 箱 に 置く
#
# 箱 に 入れる
#
# ペットボトル を 持つ
#
# ペットボトル を 把持 する
#
# ペットボトル を 拾う
#
# ペットボトル を 持つ
#
# ペットボトル を 拾う
#
# ペットボトル を 把持 する
#
# 箱 に 片付ける
#
# 箱 に しまう
#
# 箱 に 置く
#
# 箱 に 片付ける
#
# 箱 に 置く
#
# 箱 に しまう
#
# ドア を 開く
#
# ドア を 押す
#
# ドア を 押し 開ける
#
# ドア を 開く
#
# ドア を 押し 開ける
#
# ドア を 押す
#
# 冷蔵庫 を 開ける
#
# 冷蔵庫 を 覗く
#
# 冷蔵庫 を 引き 開ける
#
# 冷蔵庫 を 開ける
#
# 冷蔵庫 を 引き 開ける
#
# 冷蔵庫 を 覗く
#
# 箱 に 入れる
#
# 箱 に しまう
#
# 箱 に 片付ける
#
# 箱 に 入れる
#
# 箱 に 片付ける
#
# 箱 に しまう
#
# 箱 に 入れる
#
# 箱 に しまう
#
# 箱 に 置く
#
# 箱 に 入れる
#
# 箱 に 置く
#
# 箱 に しまう
#
# ペットボトル を 把持 する
#
# ペットボトル を 掴む
#
# ペットボトル を 拾う
#
# ペットボトル を 把持 する
#
# ペットボトル を 拾う
#
# ペットボトル を 掴む
#
# 箱 に 置く
#
# 箱 に しまう
#
# 箱 に 片付ける
#
# 箱 に 置く
#
# 箱 に 片付ける
#
# 箱 に しまう
#
# 箱 に 置く
#
# 箱 に しまう
#
# 箱 に 片付ける
#
# 箱 に 置く
#
# 箱 に 片付ける
#
# 箱 に しまう
#
# 箱 に 入れる
#
# 箱 に しまう
#
# 箱 に 片付ける
#
# 箱 に 入れる
#
# 箱 に 片付ける
#
# 箱 に しまう
#
# ドア を 開く
#
# ドア を 開ける
#
# ドア を 押し 開ける
#
# ドア を 開く
#
# ドア を 押し 開ける
#
# ドア を 開ける
#
# 冷蔵庫 を 引き 開ける
#
# 冷蔵庫 を 開ける
#
# 冷蔵庫 を 開く
#
# 冷蔵庫 を 引き 開ける
#
# 冷蔵庫 を 開く
#
# 冷蔵庫 を 開ける
#
# ペットボトル を 掴む
#
# ペットボトル を 持つ
#
# ペットボトル を 拾う
#
# ペットボトル を 掴む
#
# ペットボトル を 拾う
#
# ペットボトル を 持つ
#
# 箱 に しまう
#
# 箱 に 片付ける
#
# 箱 に 入れる
#
# 箱 に しまう
#
# 箱 に 入れる
#
# 箱 に 片付ける
#
# ペットボトル を 拾う
#
# ペットボトル を 持つ
#
# ペットボトル を 把持 する
#
# ペットボトル を 拾う
#
# ペットボトル を 把持 する
#
# ペットボトル を 持つ
#
# 箱 に 置く
#
# 箱 に 片付ける
#
# 箱 に しまう
#
# 箱 に 置く
#
# 箱 に しまう
#
# 箱 に 片付ける
#
# ペットボトル を 持つ
#
# ペットボトル を 拾う
#
# ペットボトル を 掴む
#
# ペットボトル を 持つ
#
# ペットボトル を 掴む
#
# ペットボトル を 拾う
#
# 箱 に 置く
#
# 箱 に 入れる
#
# 箱 に しまう
#
# 箱 に 置く
#
# 箱 に しまう
#
# 箱 に 入れる
#
# 箱 に 入れる
#
# 箱 に 片付ける
#
# 箱 に 置く
#
# 箱 に 入れる
#
# 箱 に 置く
#
# 箱 に 片付ける
#
# 箱 に 置く
#
# 箱 に しまう
#
# 箱 に 片付ける
#
# 箱 に 置く
#
# 箱 に 片付ける
#
# 箱 に しまう
#
# ドア を 開く
#
# ドア を 開ける
#
# ドア を 押し 開ける
#
# ドア を 開く
#
# ドア を 押し 開ける
#
# ドア を 開ける
#
# 冷蔵庫 を 引き 開ける
#
# 冷蔵庫 を 開ける
#
# 冷蔵庫 を 開く
#
# 冷蔵庫 を 引き 開ける
#
# 冷蔵庫 を 開く
#
# 冷蔵庫 を 開ける

# %%
words_hists = []
for i in range(150):
    word_hist_path = os.path.join(iwata_data_path,"RecogData/words/{0:03d}/hist.txt".format(i))
    words_hists.append(np.loadtxt(word_hist_path))

# %%
np.savetxt(os.path.join(iwata_data_path,"RecogData/words.All"),np.array(words_hists),fmt="%d")

# %%
action_num_list = []
for task_id in range(14):
    action_num = len(glob.glob(os.path.join(iwata_data_path,"task_{0}".format(task_id),"action*")))
    action_num_list.append(action_num)

# %%
np.savetxt("/home/robocup/Desktop/miyazawa_crest_2018/mmlda_single/action_nums.txt",action_num_list,fmt="%d")

# %%
all_sentence = []
for i in range(150):
    word_hist_path = os.path.join(iwata_data_path,"RecogData/words/{0:03d}/sentences.txt".format(i))
    tmp_sen_list = np.loadtxt(word_hist_path,dtype=str,delimiter="\n").tolist()
    if type(tmp_sen_list) is str:
        tmp_sen_list = [tmp_sen_list]
    all_sentence.extend(tmp_sen_list)
sentences_path = os.path.join(iwata_data_path,"RecogData/words/sentences.txt")
np.savetxt(sentences_path,all_sentence,fmt="%s")

# %%
print all_sentence[0]
# Out:
# 箱 に 置く

# %% [markdown]
# 進捗
# ドアを作っているところ
# 物体の情報を
#
# jointトラジェクトリー
#
# 場所概念の可視化
#
# 場所概念
# 既知概念環境で
#
# GP-HSMM:rosbagで学習できる
# IK:シグバース
# 学習データ：
#
#
# 場所概念の学習時間：
